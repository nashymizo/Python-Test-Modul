# %% [markdown]
# Multiplikationstabelle - Erzeuge die 1er bis 10er Multiplikationstabellen.

# %%
multiplikator = 0
for i in range(1,11):
    multiplikator += 1

    for j in range(1,11):
        ergebnis = i*multiplikator
        print(f"{i} x {multiplikator} = {ergebnis}")
# Out:
# 1 x 1 = 1
# 1 x 1 = 1
# 1 x 1 = 1
# 1 x 1 = 1
# 1 x 1 = 1
# 1 x 1 = 1
# 1 x 1 = 1
# 1 x 1 = 1
# 1 x 1 = 1
# 1 x 1 = 1
# 2 x 2 = 4
# 2 x 2 = 4
# 2 x 2 = 4
# 2 x 2 = 4
# 2 x 2 = 4
# 2 x 2 = 4
# 2 x 2 = 4
# 2 x 2 = 4
# 2 x 2 = 4
# 2 x 2 = 4
# 3 x 3 = 9
# 3 x 3 = 9
# 3 x 3 = 9
# 3 x 3 = 9
# 3 x 3 = 9
# 3 x 3 = 9
# 3 x 3 = 9
# 3 x 3 = 9
# 3 x 3 = 9
# 3 x 3 = 9
# 4 x 4 = 16
# 4 x 4 = 16
# 4 x 4 = 16
# 4 x 4 = 16
# 4 x 4 = 16
# 4 x 4 = 16
# 4 x 4 = 16
# 4 x 4 = 16
# 4 x 4 = 16
# 4 x 4 = 16
# 5 x 5 = 25
# 5 x 5 = 25
# 5 x 5 = 25
# 5 x 5 = 25
# 5 x 5 = 25
# 5 x 5 = 25
# 5 x 5 = 25
# 5 x 5 = 25
# 5 x 5 = 25
# 5 x 5 = 25
# 6 x 6 = 36
# 6 x 6 = 36
# 6 x 6 = 36
# 6 x 6 = 36
# 6 x 6 = 36
# 6 x 6 = 36
# 6 x 6 = 36
# 6 x 6 = 36
# 6 x 6 = 36
# 6 x 6 = 36
# 7 x 7 = 49
# 7 x 7 = 49
# 7 x 7 = 49
# 7 x 7 = 49
# 7 x 7 = 49
# 7 x 7 = 49
# 7 x 7 = 49
# 7 x 7 = 49
# 7 x 7 = 49
# 7 x 7 = 49
# 8 x 8 = 64
# 8 x 8 = 64
# 8 x 8 = 64
# 8 x 8 = 64
# 8 x 8 = 64
# 8 x 8 = 64
# 8 x 8 = 64
# 8 x 8 = 64
# 8 x 8 = 64
# 8 x 8 = 64
# 9 x 9 = 81
# 9 x 9 = 81
# 9 x 9 = 81
# 9 x 9 = 81
# 9 x 9 = 81
# 9 x 9 = 81
# 9 x 9 = 81
# 9 x 9 = 81
# 9 x 9 = 81
# 9 x 9 = 81
# 10 x 10 = 100
# 10 x 10 = 100
# 10 x 10 = 100
# 10 x 10 = 100
# 10 x 10 = 100
# 10 x 10 = 100
# 10 x 10 = 100
# 10 x 10 = 100
# 10 x 10 = 100
# 10 x 10 = 100

# %% [markdown]
# Stelle dir vor, du hast eine Klasse mit 4 Reihen, und jede Reihe hat 5 Sitzplätze.
#
# Die Plätze sollen in einer verschachtelten Liste gespeichert werden. Jeder Platz enthält den Namen eines Schülers (als String).
#
# 1. Erstelle eine verschachtelte Liste sitzplan, in der die Namen der Schüler gespeichert sind.
# 2. Schreibe ein Programm, das:
# 	- Alle Namen in Reihe 2 (Index 1) ausgibt.
# 	- Den 3. Sitzplatz in Reihe 3 (Index 2, Sitz 2) ausgibt.
# 	- Alle Schüler Spalte 1 (also den ersten Sitz jeder Reihe) ausgibt.
# 	- Einen bestimmten Schüler durch "Frei" ersetzt (z. B. "Nina" → "Frei").

# %% [markdown]
# weitere Aufgaben zu der Schülerliste
# - Finde alle Schüler, deren Name mit "A" beginnt.
# - Zähle, wie viele Schüler insgesamt im Sitzplan sind.
# - Erstelle eine flache Liste mit allen Namen.
# - Suche einen bestimmten Schüler (z. B. "Mert") und gib seine Position als (reihe, platz) aus.
