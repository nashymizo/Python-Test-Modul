# %%
import random
from random import randint
lottozahlen = []
for zahlen in range(6):
    randy = randint(6, 49)
    lottozahlen.append(randy)

print(lottozahlen)
# Out:
# [49, 22, 39, 36, 34, 19]

# %% [markdown]
# Es soll ein Lottozahlen Generator gebaut werden für die Zahlen
# 6 aus 49
#
# 6 Zahlen sollen gezogen werden. Diese dürfen nicht doppelt vorkommen
#
#
# Die Lösung soll in einer schleife sein.
# Die sample() Methode soll nicht genutzt werden

# %%
import random
from random import randint
lottozahlen = []

while len(lottozahlen) < 6:
    randy = randint(1, 49)

    if randy not in lottozahlen:
        lottozahlen.append(randy)


print(lottozahlen)
# Out:
# [24, 15, 1, 41, 44, 18]
