# %% [markdown]
# schreibe ein array mit allen Tagesnamen. Überlege welche Art von Array Sinn macht.

# %%
tagesnamen = (
    "Montag",
    "Dienstag",
    "Mittwoch",
    "Donnerstag",
    "Freitag",
    "Samstag",
    "Sonntag",
)

print(tagesnamen)
# Out:
# ('Montag', 'Dienstag', 'Mittwoch', 'Donnerstag', 'Freitag', 'Samstag', 'Sonntag')

# %% [markdown]
# schreibe ein array mit allen Monatsnamen. Überlege welche Art von Array Sinn macht.

# %%
monatsnamen = (
    "Januar",
    "Februar",
    "März",
    "April",
    "Mai",
    "Juni",
    "Juli",
    "August",
    "September",
    "Oktober",
    "November",
    "Dezember",
)

print(monatsnamen)
# Out:
# ('Januar', 'Februar', 'März', 'April', 'Mai', 'Juni', 'Juli', 'August', 'September', 'Oktober', 'November', 'Dezember')

# %% [markdown]
# schreibe ein array mit allen Namen aus dem Kurs (es müssen nicht alle sein(-;) Überlege welche Art von Array Sinn macht.

# %%
# schreibe ein array mit ...
# führe diese liste weiter mit eigenen ideen bis das aus den ohren herauskommt
autos = [
    "Alfa Romeo",
    "BMW",
    "Cadillac"
]

# %%
autos.append("Volkswagen")
print(autos)
autos.append("Audi")
autos.append("Suzuki")
autos.append("Honda")
autos.append("Toyota")
autos.append("Peugeot")
print(autos)
# Out:
# ['Alfa Romeo', 'BMW', 'Cadillac', 'Volkswagen', 'Volkswagen']
# ['Alfa Romeo', 'BMW', 'Cadillac', 'Volkswagen', 'Volkswagen', 'Audi', 'Suzuki', 'Honda', 'Toyota', 'Peugeot']

# %% [markdown]
# Aufgabe: Palindrom erkennen

# %%
wort = "Lagerregal"
wort1 = "Otto"
wort2 = "Anna"
wort3 = "Nico"

word_clean = wort.lower()
word_clean1 = wort1.lower()
word_clean2 = wort2.lower()
word_clean3 = wort3.lower()

if word_clean3 == word_clean3[::-1]:
    print(f"{word_clean3} ist ein Palindrome")

else:
    print(f"{word_clean3} ist kein Palindrome")
# Out:
# nico ist kein Palindrome
