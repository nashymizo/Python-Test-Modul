# %% [markdown]
# Erde ist falsch geschrieben. Dies soll korrigiert werden

# %%
# Erde ist falsch geschrieben. Dies soll korrigiert werden
planeten = ["Merkur", "Venus", "Errdee", "Mars" , "Jupiter", "Saturn", "Uranus", "Neptun"]

# %%
planeten.remove("Errdee")
print(planeten)
planeten
# Out:
# ['Merkur', 'Venus', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptun']

# %% [markdown]
# Erfinde ein neuen Planten zwischen Erde und Mars -> Das Ergebnis soll in einem neuen Array sein

# %%
# planeten = [p.replace("Errdee", "Erde") for p in planeten]

#################################################################

# # 1. Position von "Errdee" finden
# index = planeten.index("Errdee")
#
# # 2. Wert an genau dieser Stelle überschreiben
# planeten[index] = "Erde"

#################################################################

planeten[2] = "Erde"
print(planeten)


planeten.insert(3, "Schnulliper")

print(planeten)
# Out:
# ['Merkur', 'Venus', 'Erde', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptun']
# ['Merkur', 'Venus', 'Erde', 'Schnulliper', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptun']
